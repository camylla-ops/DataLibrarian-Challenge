# %% [markdown]
# <a href="https://colab.research.google.com/github/camylla-ops/DataLibrarian-Challenge/blob/main/DataLibrarian_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyarrow
import pandas as pd

# %%
# Link dos dados dos livros
link_acervo = "https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet"

# Carregar os dados
acervo = pd.read_parquet(link_acervo)

# %%
acervo.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
import pandas as pd

# Lista de anos e partes (2010 a 2020, partes 1 e 2)
anos = range(2010, 2021)  # 2010 até 2020
partes = [1, 2]

# Lista para armazenar todos os dados
todos_dados = []

# Loop para cada arquivo
for ano in anos:
    for parte in partes:
        # Monta o link do arquivo
        url = f"https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-{ano}{parte}.csv"

        try:
            # Importa o CSV
            df = pd.read_csv(url, encoding='latin-1', sep=',')

            # Adiciona à lista
            todos_dados.append(df)
            print(f"✅ {ano}-parte{parte} importado | Linhas: {len(df)}")

        except Exception as e:
            print(f"🚨 Erro em {ano}-parte{parte}: {str(e)}")

# Junta tudo em um único DataFrame
if todos_dados:
    dados_completos = pd.concat(todos_dados, ignore_index=True)
    print("\n📦 Importação concluída!")
    print(f"Total de registros: {len(dados_completos):,}")
    print(f"Colunas: {dados_completos.columns.tolist()}")
else:
    print("\n❌ Nenhum arquivo foi importado!")
# Out:
# ✅ 2010-parte1 importado | Linhas: 95357
# ✅ 2010-parte2 importado | Linhas: 100696
# ✅ 2011-parte1 importado | Linhas: 108547
# ✅ 2011-parte2 importado | Linhas: 120813
# ✅ 2012-parte1 importado | Linhas: 132606
# ✅ 2012-parte2 importado | Linhas: 117431
# ✅ 2013-parte1 importado | Linhas: 135090
# ✅ 2013-parte2 importado | Linhas: 124196
# ✅ 2014-parte1 importado | Linhas: 113181
# ✅ 2014-parte2 importado | Linhas: 122129
# ✅ 2015-parte1 importado | Linhas: 126738
# ✅ 2015-parte2 importado | Linhas: 98115
# ✅ 2016-parte1 importado | Linhas: 118733
# ✅ 2016-parte2 importado | Linhas: 107179
# ✅ 2017-parte1 importado | Linhas: 118714
# ✅ 2017-parte2 importado | Linhas: 110326
# ✅ 2018-parte1 importado | Linhas: 107065
# ✅ 2018-parte2 importado | Linhas: 95015
# ✅ 2019-parte1 importado | Linhas: 95839
# ✅ 2019-parte2 importado | Linhas: 83687
# ✅ 2020-parte1 importado | Linhas: 26561
# 🚨 Erro em 2020-parte2: HTTP Error 404: Not Found
#
# 📦 Importação concluída!
# ...

# %%
dados_completos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape       tipo_vinculo_usuario
# 0        2.008023e+09       ALUNO DE GRADUAÃÃO
# 1        2.008023e+09       ALUNO DE GRADUAÃÃO
# 2        2.008112e+09  ALUNO DE PÃS-GRADUAÃÃO
# ...

# %%
# Corrigir encoding
dados_completos['tipo_vinculo_usuario'] = dados_completos['tipo_vinculo_usuario'].str.encode('latin-1').str.decode('utf-8')

# %%
dados_completos.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %%
# Converter datas
for col in ['data_renovacao', 'data_emprestimo', 'data_devolucao']:
    dados_completos[col] = pd.to_datetime(dados_completos[col], errors='coerce')

# %%
# Remover duplicatas exatas
emprestimos_clean = dados_completos.drop_duplicates()
print("\n Limpeza inicial concluída - Duplicatas removidas:", len(dados_completos) - len(emprestimos_clean))
# Out:
#  Limpeza inicial concluída - Duplicatas removidas: 37

# %%
# Bloco 5: Juntar com dados do acervo
# --------------------------------------------------
dados_completos = pd.merge(
    emprestimos_clean,
    acervo,
    on='codigo_barras',
    how='left'
)

# %%
# Preencher dados faltantes
dados_completos['biblioteca'] = dados_completos['biblioteca'].fillna('Não identificada')
dados_completos['colecao'] = dados_completos['colecao'].fillna('Não catalogado')

print("\n🔗 Merge concluído - Dimensão final do dataset:", dados_completos.shape)
# Out:
# 🔗 Merge concluído - Dimensão final do dataset: (2261779, 13)
